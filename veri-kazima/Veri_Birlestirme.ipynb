# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Veri-Kazima/Model_Eğitim
# Out:
# /content/drive/MyDrive/Veri-Kazima/Model_Eğitim

# %%
# !ls
# Out:
# 6_4_2024+12-37-54_cnnturk__GenisDataSet_CSV.csv
# 6_4_2024+21-0-48_webtekno__GenisDataSet_CSV.csv
# 8_4_2024+10-54-6_pardus__GenisDataSet_CSV.csv
# 8_4_2024+11-55-1_webrazzi__GenisDataSet_CSV.csv
# 8_4_2024+15-51-3_sondakika__GenisDataSet_CSV.csv
# 8_4_2024+22-15-42_enson__GenisDataSet_CSV.csv
# 8_4_2024+23-14-42_tgrt__GenisDataSet_CSV.csv
# 8_4_2024+23-28-51_saglik_tgrt__GenisDataSet_CSV.csv
# 8_4_2024+23-29-6_egitim_tgrt__GenisDataSet_CSV.csv
# 9_4_2024+15-7-53_aktueltgrt__GenisDataSet_CSV.csv
# ShiftDelete
# Teknoloji_News_Genel_DataSet.csv
# TRT-Haber
# TRT_Haber_Genel_DataSet.csv

# %%
def kelime_sayisi(dosya_adi):
  with open(dosya_adi, "r") as dosya:
    metin = dosya.read()
  kelimeler = metin.split()
  return len(kelimeler)

# %%
import pandas as pd

# %%
haberler_DataFrame = pd.DataFrame({"Baslik":[],"Ozet":[],"Kategori":[],"Link":[],"Icerik":[]})

# %%
haber_1 = pd.read_csv('6_4_2024+12-37-54_cnnturk__GenisDataSet_CSV.csv')
haber_2 = pd.read_csv('6_4_2024+21-0-48_webtekno__GenisDataSet_CSV.csv')
haber_3 = pd.read_csv('8_4_2024+10-54-6_pardus__GenisDataSet_CSV.csv')
haber_4 = pd.read_csv('8_4_2024+11-55-1_webrazzi__GenisDataSet_CSV.csv')
haber_5 = pd.read_csv('8_4_2024+15-51-3_sondakika__GenisDataSet_CSV.csv')
haber_6 = pd.read_csv('8_4_2024+22-15-42_enson__GenisDataSet_CSV.csv')
haber_7 = pd.read_csv('8_4_2024+23-14-42_tgrt__GenisDataSet_CSV.csv')
haber_8 = pd.read_csv('8_4_2024+23-28-51_saglik_tgrt__GenisDataSet_CSV.csv')
haber_9 = pd.read_csv('8_4_2024+23-29-6_egitim_tgrt__GenisDataSet_CSV.csv')
haber_10 = pd.read_csv('9_4_2024+15-7-53_aktueltgrt__GenisDataSet_CSV.csv')
haber_11 = pd.read_csv('Teknoloji_News_Genel_DataSet.csv')
haber_12 = pd.read_csv('TRT_Haber_Genel_DataSet.csv')

# %%
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_1], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_2], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_3], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_4], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_5], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_6], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_7], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_8], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_9], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_10], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_11], ignore_index=True)
haberler_DataFrame = pd.concat([haberler_DataFrame,haber_12], ignore_index=True)

# %%
haberler_DataFrame
# Out:
#                                                    Baslik  \
# 0       Pazartesi noterler açık mı, kapalı mı? 8-9 Nis...
# 1       Memleket Partisi küçülüyor! İnce: Binaları küç...
# 2       43 ilin geçiş noktasında bayram yoğunluğu: Ara...
# 3       Dumanlar gökyüzünü kapladı: Burdur'da fabrika ...
# 4       Gerginlik mi var? Kılıçdaroğlu: İmamoğlu beni ...
# ...                                                   ...
# 113809  MEB ve ASELSAN’dan "Yeşil Geleceğim” temalı re...
# 113810               Kar kalınlığı 183 santimetre ölçüldü
# 113811  Şanlıurfa merkezli 10 ilde dolandırıcılık oper...
# 113812  e-Devlet şifre işlemleri Türksat merkezlerinde...
# 113813  "Sibergöz-14" operasyonunda yakalanan 30 şüphe...
#
#                                                      Ozet Kategori  \
# 0       Pazartesi noterler açık mı, kapalı mı? 8-9 Nis...  Türkiye
# 1       Memleket Partisi küçülüyor! İnce: Binaları küç...  Türkiye
# ...

# %%
haberler_DataFrame.drop("Unnamed: 0",axis=1,inplace=True)

# %%
haberler_DataFrame.drop("Unnamed: 0.1",axis=1,inplace=True)

# %%
haberler_DataFrame
# Out:
#                                                    Baslik  \
# 0       Pazartesi noterler açık mı, kapalı mı? 8-9 Nis...
# 1       Memleket Partisi küçülüyor! İnce: Binaları küç...
# 2       43 ilin geçiş noktasında bayram yoğunluğu: Ara...
# 3       Dumanlar gökyüzünü kapladı: Burdur'da fabrika ...
# 4       Gerginlik mi var? Kılıçdaroğlu: İmamoğlu beni ...
# ...                                                   ...
# 113809  MEB ve ASELSAN’dan "Yeşil Geleceğim” temalı re...
# 113810               Kar kalınlığı 183 santimetre ölçüldü
# 113811  Şanlıurfa merkezli 10 ilde dolandırıcılık oper...
# 113812  e-Devlet şifre işlemleri Türksat merkezlerinde...
# 113813  "Sibergöz-14" operasyonunda yakalanan 30 şüphe...
#
#                                                      Ozet Kategori  \
# 0       Pazartesi noterler açık mı, kapalı mı? 8-9 Nis...  Türkiye
# 1       Memleket Partisi küçülüyor! İnce: Binaları küç...  Türkiye
# ...

# %%
yol = "Tum-Veri-Seti-Nisan2024-10.csv"

# %%
haberler_DataFrame.to_csv(yol)

# %%
tum_haber = pd.read_csv(yol)

# %%
tum_haber
# Out:
#         Unnamed: 0                                             Baslik  \
# 0                0  Pazartesi noterler açık mı, kapalı mı? 8-9 Nis...
# 1                1  Memleket Partisi küçülüyor! İnce: Binaları küç...
# 2                2  43 ilin geçiş noktasında bayram yoğunluğu: Ara...
# 3                3  Dumanlar gökyüzünü kapladı: Burdur'da fabrika ...
# 4                4  Gerginlik mi var? Kılıçdaroğlu: İmamoğlu beni ...
# ...            ...                                                ...
# 113809      113809  MEB ve ASELSAN’dan "Yeşil Geleceğim” temalı re...
# 113810      113810               Kar kalınlığı 183 santimetre ölçüldü
# 113811      113811  Şanlıurfa merkezli 10 ilde dolandırıcılık oper...
# 113812      113812  e-Devlet şifre işlemleri Türksat merkezlerinde...
# 113813      113813  "Sibergöz-14" operasyonunda yakalanan 30 şüphe...
#
#                                                      Ozet Kategori  \
# ...

# %%
kelime_sayisi(yol)
# Out:
# 29483666

# %%
#29.483.666
